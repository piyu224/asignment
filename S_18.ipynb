# %%
# 1. Use re.findall() to extract all valid Indian phone numbers (10 digits, starting with 7, 8, or 9) 
#    from a given text string that contains random numbers, prices, and phone numbers like those seen in OLX or WhatsApp chats.

import re

text = """
Call me on 9876543210 or 8123456789.
Price is 5000 and order number is 123456.
WhatsApp: 7012345678
"""

pattern = r'\b[789]\d{9}\b'

numbers = re.findall(pattern, text)

print(numbers)
# Out:
# ['9876543210', '8123456789', '7012345678']

# %%
# 2. Write a Python function using re.search() that checks if a given string contains a valid date in the format DD/MM/YYYY (e.g., 25/06/2024), 
#    and returns True if found, otherwise False.<br><br><em><strong>Hint:</strong> Use the pattern '\b\d{2}/\d{2}/\d{4}\b'.</em>

import re

def check_date(text):
    pattern = r'\b\d{2}/\d{2}/\d{4}\b'

    if re.search(pattern, text):
        return True
    else:
        return False

print(check_date("My birthday is 25/06/2024"))
print(check_date("Today is Monday"))
# Out:
# True
# False

# %%
# 3. Given a messy text copied from a Zomato review containing multiple emails, 
#    use re.findall() to extract all valid email addresses and print them as a list.

import re

text = """
Great food! Contact us at zomato@gmail.com
or restaurant123@yahoo.com.
Another email is food.delivery@outlook.com
"""

pattern = r'\b[\w.-]+@[\w.-]+\.\w+\b'

emails = re.findall(pattern, text)

print(emails)
# Out:
# ['zomato@gmail.com', 'restaurant123@yahoo.com', 'food.delivery@outlook.com']

# %%
# 4. Use re.sub() to mask all but the last 4 digits of any phone number in a string (e.g., replace 9876543210 with ******3210) like Paytm does for privacy.
#    <br><br><em><strong>Constraint:</strong> Do not use loops; achieve this only with re.sub().</em>

import re

text = "My phone numbers are 9876543210 and 8123456789."

masked = re.sub(r'\b[789]\d{6}(\d{4})\b', r'******\1', text)

print(masked)
# Out:
# My phone numbers are 9876543210 and 8123456789.

# %%
# 5. Use ChatGPT to generate a regex pattern that matches Flipkart-style order IDs 
#    (e.g., OD123456789012345000) and test it in Python using re.search() on sample order strings.

import re

order1 = "My Flipkart order ID is OD123456789012345000."

pattern = r'\bOD\d{18}\b'

result = re.search(pattern, order1)

if result:
    print("Valid Order ID:", result.group())
else:
    print("Invalid Order ID")
# Out:
# Valid Order ID: OD123456789012345000
