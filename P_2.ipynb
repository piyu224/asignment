# %%
! pip install pandas
# Out:
# ...
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 1. Download a CSV file of IPL match results from Kaggle or any open dataset, then use pandas read_csv() 
#   to load it into a DataFrame and display the first 10 rows using head().

import pandas as pd
df = pd.read_csv("Documents/matches.csv")

print(df.head(10))
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
# 2. Find a small Excel file of your own mobile expenses (or create one with 5-10 rows), 
#   then use pandas read_excel() to load it and print the last 3 rows using tail().

! pip install openpyxl
# Out:
# ...
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
data = {
    "Date": [
        "2026-08-25", "2026-08-26", "2026-08-27", "2026-08-28",
        "2026-08-29", "2026-08-30", "2026-08-31", "2026-09-01"
    ],
    "Expense": [
        "Mobile Recharge", "Internet Pack", "Phone Cover", "Earphones",
        "Mobile Recharge", "Data Pack", "Screen Guard", "Internet Pack"
    ],
    "Amount": [299, 199, 250, 599, 399, 149, 100, 249]
}

df = pd.DataFrame(data)

df.to_excel("mobile_expenses.xlsx", index=False)

mobile_expenses = pd.read_excel("mobile_expenses.xlsx")

print(mobile_expenses.tail(3))
# Out:
#          Date        Expense  Amount
# 5  2026-08-30      Data Pack     149
# 6  2026-08-31   Screen Guard     100
# 7  2026-09-01  Internet Pack     249

# %%
# 3. Use describe() and info() on a DataFrame loaded from a Zomato restaurant dataset (or any food delivery data you can find online), and write down 2 insights about the data (for example: number of restaurants, missing values, or average ratings).
# <br><br><em><strong>Hint:</strong> Focus on what info() and describe() reveal about columns and data types.</em>

import pandas as pd

df = pd.read_csv("Documents/Zomato-data-.csv")

print("DataFrame Information:")
df.info()

print("\nStatistical Description:")
print(df.describe())
# Out:
# DataFrame Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    str
#  1   online_order                 148 non-null    str
#  2   book_table                   148 non-null    str
#  3   rate                         148 non-null    str
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    str
# dtypes: int64(2), str(5)
# memory usage: 8.2 KB
#
# Statistical Description:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# ...

# %%
# 4. Export the DataFrame from your IPL or food delivery dataset 
#   to a new CSV file called 'filtered_data.csv', but only include the first 20 rows

filtered_data = df.head(20)

filtered_data.to_csv("filtered_data.csv", index=False)

print("File exported successfully!")
print(filtered_data)
# Out:
# File exported successfully!
#                                                name online_order book_table  \
# 0                                             Jalsa          Yes        Yes
# 1                                    Spice Elephant          Yes         No
# 2                                   San Churro Cafe          Yes         No
# 3                             Addhuri Udupi Bhojana           No         No
# 4                                     Grand Village           No         No
# 5                                   Timepass Dinner          Yes         No
# 6   Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                            Onesta          Yes        Yes
# 8                                    Penthouse Cafe          Yes         No
# 9                                         Smacznego          Yes         No
# 10                                     Village Café          Yes         No
# ...

# %%
# 5. Load any dataset of your choice (not the one used in the class demo),
# and export it to Excel format with a custom sheet name like 'Analysis2024'.
# <br><br><em><strong>Constraint:</strong> Use the to_excel() method and set the sheet_name parameter.</em>

import pandas as pd
data = {
    "Student": ["Rahul", "Priya", "Amit", "Sneha", "Rohit"],
    "Python": [85, 92, 78, 88, 75],
    "Java": [80, 89, 76, 90, 72],
    "SQL": [88, 95, 82, 85, 78]
}

df = pd.DataFrame(data)

print("Student Marks Dataset:")
print(df)

df.to_excel("student_marks.xlsx", sheet_name="Analysis2024", index=False)

print("\nExcel file exported successfully!")
print("File name: student_marks.xlsx")
print("Sheet name: Analysis2024")
# Out:
# Student Marks Dataset:
#   Student  Python  Java  SQL
# 0   Rahul      85    80   88
# 1   Priya      92    89   95
# 2    Amit      78    76   82
# 3   Sneha      88    90   85
# 4   Rohit      75    72   78
#
# Excel file exported successfully!
# File name: student_marks.xlsx
# Sheet name: Analysis2024
