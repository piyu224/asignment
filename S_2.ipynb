# %%
# 1. Create three variables in Python: user_name, fav_app, and daily_usage_hours. Assign your own name,
#    your favorite app (like Instagram or Zomato), and how many hours you use it daily.

user_name = "Pragati"
fav_app = "Instagram"
daily_usage_hours = 4

print(user_name)
print(fav_app)
print(daily_usage_hours)
# Out:
# Pragati
# Instagram
# 4

# %%
# 2. Write a Python script that declares variables for product_name, price,and is_available to represent an item on Flipkart.
#    Print each variable and its data type using the type() function.

product_name = "Boat Earphones"
price = 799
is_available = True

print(product_name)
print(type(product_name))

print(price)
print(type(price))

print(is_available)
print(type(is_available))
# Out:
# Boat Earphones
# <class 'str'>
# 799
# <class 'int'>
# True
# <class 'bool'>

# %%
# 3. Demonstrate the difference between single-line and multi-line comments in Python by writing a script that explains how a Spotify playlist recommendation system might work. 
#    Use # for single-line and triple quotes for multi-line comments.

# Spotify recommends songs based on your listening history.

"""
Spotify playlist recommendation system works like this:
1. It checks the songs you listen to.
2. It finds your favorite artists and genres.
3. It suggests similar songs and playlists.
4. It updates recommendations based on your activity.
"""

print("Spotify Playlist Recommendation System")
# Out:
# Spotify Playlist Recommendation System

# %%
# 4. Create variables for order_total, delivery_region, and discount_percent to represent a Zomato order.
#     Follow Python naming conventions and print a sentence using all three variables, 
#     like 'Order from [region] totals ₹[order_total] with [discount_percent]% discount.'

# Create variables

order_total = 550
delivery_region = "Pune"
discount_percent = 20

# Print the order details

print(f"Order from {delivery_region} totals ₹{order_total} with {discount_percent}% discount.")
# Out:
# Order from Pune totals ₹550 with 20% discount.

# %%
# 5. Write a Python script that intentionally mixes tabs and spaces for indentation, then fix the script so it runs without errors.
#    <br><br><em><strong>Hint:</strong> Use only spaces for indentation, as per Python's best practices.</em>

if True:
    print("Hello")
    print("Welcome")
# Out:
# Hello
# Welcome
