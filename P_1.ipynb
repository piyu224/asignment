# %%
# 1. Install pandas in your Python environment and create a Series named 'fav_cricket_teams' 
#   containing the names of your 5 favorite IPL teams. Print the Series.

! pip install pandas
# Out:
# ...
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\WIN10\AppData\Local\Programs\Python\Python314\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

fav_cricket_teams = pd.Series(["MI","RCB","CSK","GT","KKR"])
print(fav_cricket_teams)
# Out:
# 0     MI
# 1    RCB
# 2    CSK
# 3     GT
# 4    KKR
# dtype: str

# %%
# 2. Create a DataFrame named 'food_orders' with columns: 'Item', 'Restaurant', and 'Price'. 
#  Add 3 rows representing your last 3 Zomato or Swiggy orders and display the DataFrame.

import pandas as pd

food_orders = pd.DataFrame({
    "Item": ["Pizza", "Burger", "Biryani"],
    "Restaurant": ["Domino's", "McDonald's", "Behrouz Biryani"],
    "Price": [299, 199, 249]
})
print(food_orders)
# Out:
#       Item       Restaurant  Price
# 0    Pizza         Domino's    299
# 1   Burger       McDonald's    199
# 2  Biryani  Behrouz Biryani    249

# %%
# 3.Given a list of follower counts for 5 Instagram influencers: 
# [1200, 54000, 780, 150000, 32000], create a pandas Series called 'followers',
# then print the influencer(s)with the highest and lowest follower counts.
# <br><br><em><strong>Hint:</strong> Use Series.idxmax() and Series.idxmin() to find the indices.</em>

import pandas as pd

followers = pd.Series([1200, 54000, 780, 150000, 32000])

highest = followers.idxmax()
lowest = followers.idxmin()

print("Highest followers:", followers[highest])
print("Highest influencer index:", highest)

print("Lowest followers:", followers[lowest])
print("Lowest influencer index:", lowest)
# Out:
# Highest followers: 150000
# Highest influencer index: 3
# Lowest followers: 780
# Lowest influencer index: 2

# %%
# 4. Create a DataFrame called 'playlist' with columns: 'Song', 'Artist', and 'Duration' (in minutes). 
# Enter details for 4 songs you recently listened to on Spotify or YouTube Music, then print only the 'Song' and 'Duration' columns.

import pandas as pd
playlist = pd.DataFrame({
    "Song": ["Kesariya", "Apna Bana Le", "Heeriye", "Tum Kya Mile"],
    "Artist": ["Arijit Singh", "Arijit Singh", "Jasleen Royal", "Arijit Singh"],
    "Duration": [4.28, 4.21, 3.15, 4.37]
})
print(playlist[["Song", "Duration"]])
# Out:
#            Song  Duration
# 0      Kesariya      4.28
# 1  Apna Bana Le      4.21
# 2       Heeriye      3.15
# 3  Tum Kya Mile      4.37
