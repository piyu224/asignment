# %%
# 1. Use the math module to calculate the square root, factorial, and value of pi for given numbers, and print each result.

import math

num = 5

square_root = math.sqrt(num)
factorial = math.factorial(num)
pi_value = math.pi

print("Square Root:", square_root)
print("Factorial:", factorial)
print("Value of Pi:", pi_value)
# Out:
# Square Root: 2.23606797749979
# Factorial: 120
# Value of Pi: 3.141592653589793

# %%
# 2. Write a script that lists all files in your current directory using the os module, and prints only those files with a .jpg or .png extension.
#    <br><br><em><strong>Hint:</strong> Use os.listdir() and string methods to filter file names.</em>

import os

open("photo.jpg", "w").close()
open("image.png", "w").close()
open("logo.jpg", "w").close()

for file in os.listdir():
    if file.endswith((".jpg", ".png")):
        print(file)
# Out:
# image.png
# logo.jpg
# photo.jpg

# %%
# 3. Create a Python program that accepts a date in 'YYYY-MM-DD' format from the user and displays the day of the week using the datetime module.

from datetime import datetime
date = input("Enter date (YYYY-MM-DD): ")
date_object = datetime.strptime(date, "%Y-%m-%d")
day = date_object.strftime("%A")

print("Day:", day)
# Out:
# Enter date (YYYY-MM-DD):  2005-10-30
# Day: Sunday

# %%
# 4. Build a simple custom module named insta_utils.py with a function format_follower_count(n) that returns '1.5K' for 1500 and '2.3M' for 2300000. 
#    Import and use this function in another script to display formatted counts for 3 sample numbers.

with open("insta_utils.py", "w") as file:
    file.write(code)

print("insta_utils.py created successfully")
# Out:
# insta_utils.py created successfully

# %%
def format_follower_count(n):
    if n >= 1000000:
        return f"{n / 1000000:.1f}M"
    elif n >= 1000:
        return f"{n / 1000:.1f}K"
    else:
        return str(n)

# %%
from insta_utils import format_follower_count

print(format_follower_count(1500))
print(format_follower_count(2300000))
print(format_follower_count(850))
# Out:
# 1.5K
# 2.3M
# 850

# %%
# 5. Create a new virtual environment using venv, activate it, and install the statistics and requests packages via pip. 
#    Then, write a script that uses statistics.mean() to calculate the average of a list of numbers.

import statistics

numbers = [10, 20, 30, 40, 50]

average = statistics.mean(numbers)

print("Average:", average)
# Out:
# Average: 30
